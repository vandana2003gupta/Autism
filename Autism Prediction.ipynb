# %%
import numpy as np
import pandas as pd
df = pd.read_csv("autism_screening.csv")
df
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0           1         1         1         1         0         0         1
# 1           1         1         0         1         0         0         0
# 2           1         1         0         1         1         0         1
# 3           1         1         0         1         0         0         1
# 4           1         0         0         0         0         0         0
# ..        ...       ...       ...       ...       ...       ...       ...
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice  \
# ...

# %%
df.describe()
# Out:
#          A1_Score    A2_Score    A3_Score    A4_Score    A5_Score    A6_Score  \
# count  704.000000  704.000000  704.000000  704.000000  704.000000  704.000000
# mean     0.721591    0.453125    0.457386    0.495739    0.498580    0.284091
# std      0.448535    0.498152    0.498535    0.500337    0.500353    0.451301
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          A7_Score    A8_Score    A9_Score   A10_Score         age      result
# count  704.000000  704.000000  704.000000  704.000000  702.000000  704.000000
# mean     0.417614    0.649148    0.323864    0.573864   29.698006    4.875000
# ...

# %%
df.head()
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         0
#
#    A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice austim  \
# 0         1         0          0  ...       f  White-European      no     no
# 1         1         0          1  ...       m          Latino      no    yes
# 2         1         1          1  ...       m          Latino     yes    yes
# 3         1         0          1  ...       f  White-European      no    yes
# 4         1         0          0  ...       f               ?      no     no
#
# ...

# %%
df.tail()
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice  \
# 699         1         1          1  ...       f  White-European      no
# 700         1         0          1  ...       m        Hispanic      no
# 701         1         0          1  ...       f               ?      no
# 702         0         1          1  ...       m     South Asian      no
# 703         1         1          1  ...       f  White-European      no
#
#     austim contry_of_res used_app_before result     age_desc relation  \
# ...

# %%
df.isnull()
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0       False     False     False     False     False     False     False
# 1       False     False     False     False     False     False     False
# 2       False     False     False     False     False     False     False
# 3       False     False     False     False     False     False     False
# 4       False     False     False     False     False     False     False
# ..        ...       ...       ...       ...       ...       ...       ...
# 699     False     False     False     False     False     False     False
# 700     False     False     False     False     False     False     False
# 701     False     False     False     False     False     False     False
# 702     False     False     False     False     False     False     False
# 703     False     False     False     False     False     False     False
#
#      A8_Score  A9_Score  A10_Score  ...  gender  ethnicity  jundice  austim  \
# ...

# %%
df.shape
# Out:
# (704, 21)

# %%
df.isnull()
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0       False     False     False     False     False     False     False
# 1       False     False     False     False     False     False     False
# 2       False     False     False     False     False     False     False
# 3       False     False     False     False     False     False     False
# 4       False     False     False     False     False     False     False
# ..        ...       ...       ...       ...       ...       ...       ...
# 699     False     False     False     False     False     False     False
# 700     False     False     False     False     False     False     False
# 701     False     False     False     False     False     False     False
# 702     False     False     False     False     False     False     False
# 703     False     False     False     False     False     False     False
#
#      A8_Score  A9_Score  A10_Score  ...  gender  ethnicity  jundice  austim  \
# ...

# %%
df.isnull().sum()
# Out:
# A1_Score           0
# A2_Score           0
# A3_Score           0
# A4_Score           0
# A5_Score           0
# A6_Score           0
# A7_Score           0
# A8_Score           0
# A9_Score           0
# A10_Score          0
# age                2
# gender             0
# ethnicity          0
# jundice            0
# austim             0
# contry_of_res      0
# used_app_before    0
# result             0
# age_desc           0
# relation           0
# Class/ASD          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704 entries, 0 to 703
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   A1_Score         704 non-null    int64
#  1   A2_Score         704 non-null    int64
#  2   A3_Score         704 non-null    int64
#  3   A4_Score         704 non-null    int64
#  4   A5_Score         704 non-null    int64
#  5   A6_Score         704 non-null    int64
#  6   A7_Score         704 non-null    int64
#  7   A8_Score         704 non-null    int64
#  8   A9_Score         704 non-null    int64
#  9   A10_Score        704 non-null    int64
#  10  age              702 non-null    float64
#  11  gender           704 non-null    object
#  12  ethnicity        704 non-null    object
#  13  jundice          704 non-null    object
#  14  austim           704 non-null    object
#  15  contry_of_res    704 non-null    object
#  16  used_app_before  704 non-null    object
# ...

# %%
import seaborn as sns
sns.heatmap(df.corr(),cbar=False,cmap='BuGn',annot=True)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.heatmap(df.corr(),cbar=False,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 'A6_Score',
#        'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'age', 'gender',
#        'ethnicity', 'jundice', 'austim', 'contry_of_res', 'used_app_before',
#        'result', 'age_desc', 'relation', 'Class/ASD'],
#       dtype='object')

# %%
import seaborn as sns
from matplotlib import pyplot as plt
for i in df.columns:
  plt.figure(figsize= (13.7,4.5))
  sns.countplot(data = df ,x=i)
  plt.show()

# %%
p=df.hist(figsize = (20,20))

# %%
sns.pointplot(x='ethnicity', y= 'result', data= df)
plt.figure(figsize= (19.7,19.5))

# %%
sns.pointplot(x='ethnicity', y= 'age', data= df)
plt.figure(figsize= (19.7,19.5))

# %%
sns.scatterplot(x='age',y='used_app_before',data=df)
# Out:
# <AxesSubplot:xlabel='A10_Score', ylabel='used_app_before'>

# %%
sns.boxplot(x='age',y='result',data=df)
plt.figure(figsize= (13.7,4.5))

# %%
sns.pairplot(df,hue='Class/ASD')

# %%
import seaborn as sn
from matplotlib import pyplot as plt
plt.figure(figsize=(14,4))
sn.countplot(data=df, x=df.result)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.xlabel("A1_Score ")
plt.ylabel("Class/ASD")
a=df[4:14]
plt.plot(a.A1_Score, a.result, color='green', marker ='o')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.xlabel("A2_Score ")
plt.ylabel("Class/ASD")
a=df[4:14]
plt.plot(a.A1_Score, a.result, color='green', marker ='o')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_648\2157028881.py in <module>
#       4 mylabels=["A1_Score","A2_Score","A3_Score","A4_Score","A5_Score",]
#       5 autopct = '%1.1f%%'
# ----> 6 plt.pie( labels=mylabels, autopct=autopct)
#       7 plt.title("Autism")
#       8 plt.show()
#
# TypeError: pie() missing 1 required positional argument: 'x'
